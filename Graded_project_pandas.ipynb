# %% [markdown]
# <a href="https://colab.research.google.com/github/Manversajjad/Project_pandas/blob/main/Graded_project_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 2
# ## Graded Comprehension 1: IMDb Movies

# %% [markdown]
# You are given the following data for movies released between 1916 and 2016. You are expected to find interesting insights using Python. You can download the movie dataset from the following link.
#
# [movies_IMDB_dataset.csv](https://drive.google.com/file/d/1qColINjV5_DZ2OrtK1E2hTrhapj898Mh/view?usp=sharing)
#
# Each column of the dataset is explained below.
# <br>
#
# | Column Name | Description |
# | :- |:-: |
# | movie_title | Title of the movie |
# | color | Whether the movie is in color or black and white |
# | director_name | Name of the director |
# | num_critic_for_reviews | Number of critic reviews for the movie |
# | duration | Duration of the movie |
# | director_facebook_likes | Number of likes on the director’s Facebook page |
# | actor_3_facebook_likes | Number of likes on supporting actor 2’s Facebook page |
# | actor_2_name | Name of supporting actor 1 |
# | actor_1_facebook_likes | Number of likes on the main actor’s Facebook page |
# | gross | Total earnings at the box office |
# | genres | Genre of the movie (May be multiple genres separated by a '|'. The first one is the primary genre for the movie.) |
# | actor_1_name | Name of the main actor |
# | num_voted_users | Total number of votes/ratings |
# | cast_total_facebook_likes | Total likes on the cast’s Facebook pages |
# | actor_3_name | Name of supporting actor 2 |
# | facenumber_in_poster | Number of faces on the poster |
# | plot_keywords | Keywords for the plot |
# | movie_imdb_link | Link to IMDb page listing for the movie |
# | num_user_for_reviews | Total number of user reviews (text reviews) |
# | language | Language in which the movie was originally shot |
# | country | Country of origin for the movie production |
# | content_rating | Age rating for the movie |
# | budget | Budget required to make the movie |
# | title_year | Year of release |
# | actor_2_facebook_likes | Number of likes on the supporting actor’s Facebook page |
# | imdb_score | IMDb score of the movie |
# | aspect_ratio | Aspect ratio of the movie footage |
# | movie_facebook_likes | Number of likes on the movie’s Facebook page |
#
# <br>
#
# You can use this Jupyter Notebook to answer the questions. You are expected to load the data into a DataFrame named **movies**.

# %%
import pandas as pd
import numpy as np

# %%
# Importing file from the location
importing_csv_file = pd.read_csv(r'/content/movies_IMDB_dataset.csv')
importing_csv_file.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color     Andrew Stanton                   462.0     132.0
# 5  Color          Sam Raimi                   392.0     156.0
# 6  Color       Nathan Greno                   324.0     100.0
# 7  Color        Joss Whedon                   635.0     141.0
# 8  Color        David Yates                   375.0     153.0
# 9  Color        Zack Snyder                   673.0     183.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# ...

# %% [markdown]
# **Question 1**: For this assignment, analyze features from the IMDb movie dataset. Exclude the following list of features from your analysis:
# *   color
# *   director_facebook_likes
# *   actor_1_facebook_likes
# *   actor_2_facebook_likes
# *   actor_3_facebook_likes
# *   actor_2_name
# *   cast_total_facebook_likes
# *   actor_3_name
# *   duration
# *   facenumber_in_poster
# *   content_rating
# *   country
# *   movie_imdb_link
# *   aspect_ratio
# *   plot_keywords
#
# <br>
#
# Which of the following would you use to permanently drop the columns <code>["color", "director_facebook_likes", …"aspect_ratio", "plot_keywords"]</code> from the DataFrame **movies**?
#
# A. movies.drop(["color", "director_facebook_likes", …"aspect_ratio", "plot_keywords"], inplace = True)\
# B. movies.drop(["color", "director_facebook_likes", …"aspect_ratio", "plot_keywords"], axis = 1) \
# C. movies.drop(["color", "director_facebook_likes", …"aspect_ratio", "plot_keywords"], axis = 1, inplace = True)\
# D. movies.drop("color", "director_facebook_likes", …"aspect_ratio", "plot_keywords", axis = 1, inplace = True)

# %% [markdown]
# *List of columns to be dropped:*
#
# ['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio', 'plot_keywords']

# %%
# Write your code here
columns_to_drop = ['color', 'director_facebook_likes', 'actor_1_facebook_likes', 'actor_2_facebook_likes',
                   'actor_3_facebook_likes', 'actor_2_name', 'cast_total_facebook_likes', 'actor_3_name',
                   'duration', 'facenumber_in_poster', 'content_rating', 'country', 'movie_imdb_link',
                   'aspect_ratio', 'plot_keywords']

importing_csv_file.drop(columns=columns_to_drop, inplace=True)

# %%
importing_csv_file
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 3848      Shane Carruth                   143.0     424760.0
# 3849   Neill Dela Llana                    35.0      70071.0
# 3850   Robert Rodriguez                    56.0    2040920.0
# 3851       Edward Burns                    14.0       4584.0
# 3852           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# **Question 2**: What is the total count of movies made in the English language?\
# A. 3674 \
# B. 3671 \
# C. 3668 \
# D. 3677

# %%
# Shape returns the actual number when the condition is being compared. We can also use value_count() function to get the same result
english_Language = importing_csv_file[importing_csv_file['language'] == 'English'].shape[0]
english_Language
# Out:
# 3671

# %% [markdown]
# **Question 3**: Find the movie with the highest profit. Estimate a movie’s profit by subtracting the column 'budget' from the column 'gross'.<br>
# **Hint:** You can add an additional column ‘profit’ to the DataFrame.
#
# A.  *Titanic* \
# B.  *Avatar* \
# C.  *The Avengers* \
# D.  *The Dark Knight*

# %%
# Write your code here
movies_profit = importing_csv_file['budget'] - importing_csv_file['gross']
importing_csv_file['profit'] = movies_profit
importing_csv_file['profit'].max()
importing_csv_file['movie_title']
# Out:
# 0                                           Avatar
# 1         Pirates of the Caribbean: At World's End
# 2                                          Spectre
# 3                            The Dark Knight Rises
# 4                                      John Carter
#                             ...
# 3849                                        Cavite
# 3850                                   El Mariachi
# 3851                                     Newlyweds
# 3852                             My Date with Drew
# profit                                         NaN
# Name: movie_title, Length: 3854, dtype: object

# %% [markdown]
# **Question 4**: What is the IMDb score for the movie ‘*The Dark Knight*’?
#
# A.  7.9 \
# B.  8.4 \
# C.  9.0 \
# D.  9.3

# %%
# Write your code here
Scoring_imdb = importing_csv_file[importing_csv_file['movie_title'] == 'The Dark Knight']
importing_csv_file['imdb_score']
Scoring_imdb
# Out:
#         director_name  num_critic_for_reviews        gross  \
# 64  Christopher Nolan                   645.0  533316061.0
#
#                          genres    actor_1_name      movie_title  \
# 64  Action|Crime|Drama|Thriller  Christian Bale  The Dark Knight
#
#     num_voted_users  num_user_for_reviews language       budget  title_year  \
# 64          1676169                4667.0  English  185000000.0      2008.0
#
#     imdb_score  movie_facebook_likes
# 64         9.0                 37000

# %% [markdown]
# **Question 5**: What is the average IMDb score for the movies starring Leonardo DiCaprio as the first actor?
#
# A. 6.8 \
# B. 7.3 \
# C. 7.5 \
# D. 8.2

# %%
# Write your code here
avg_score = importing_csv_file[importing_csv_file['actor_1_name'] == 'Leonardo DiCaprio']
avg_score['imdb_score'].mean()
# Out:
# 7.495238095238095
